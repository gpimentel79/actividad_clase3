# %% [markdown]
# # Actividad N° 3 de Programación II
#
# ### Ejercicios de Datos Complejos en Python
#
# + Crear una lista de nombres de ciudades.

# %%
ciudades =["Río Grande","Tolhuin","Ushuaia"]

# %% [markdown]
# + Crear un diccionario con información de empleados (nombre, cargo, salario).

# %%
empleados ={"1":{"nombre":"carlos","cargo":"gerente","salario":500000},
            "2":{"nombre":"facundo","cargo":"analista de datos","salario":350000}}

# %% [markdown]
# + Mostrar cómo acceder a un elemento específico en una lista y en un diccionario.

# %%
rio_grande=ciudades[0]
print(rio_grande)
# Out:
# Río Grande

# %%
print("Primer ciudad",ciudades[0])
# Out:
# Primer ciudad Río Grande

# %%
print(empleados["1"])
# Out:
# {'nombre': 'carlos', 'cargo': 'gerente', 'salario': 500000}

# %%
empleados_2={"juan":["cadete",120],
             "carlos":["contador",220],
             "ana":["jefe",250]}

# %%
print("Sueldo Carlos",empleados_2["carlos"][1],"dolares")
# Out:
# Sueldo Carlos 220 dolares

# %% [markdown]
# + Crea una lista inicial de números enteros.
# + Utiliza el método .append() para agregar un número al final de la lista.
# + Utiliza el método .extend() para agregar múltiples elementos a la lista.
# + Utiliza el método .insert() para insertar un número en una posición específica de la lista.
# + Muestra cómo utilizar el método .sort() para ordenar la lista de números de forma ascendente.

# %%
numeros =[5,15,2,10,25]
numeros.append(35)
numeros2=[50,1,30]
numeros.extend(numeros2)

# %%
print(numeros)
# Out:
# [5, 15, 2, 10, 25, 35, 50, 1, 30]

# %%
numeros.insert(2,12)

# %%
print(numeros)
# Out:
# [5, 15, 12, 2, 10, 25, 35, 50, 1, 30]

# %%
numeros.sort()

# %%
print(numeros)
# Out:
# [1, 2, 5, 10, 12, 15, 25, 30, 35, 50]

# %% [markdown]
# + Crea un diccionario con información de productos (nombre del producto, precio, cantidad en stock).
# + Utiliza el método .keys() para obtener una lista de las llaves (nombres de productos) en el diccionario.
# + Utiliza el método .values() para obtener una lista de los valores (precios y cantidades) en el diccionario.
# + Utiliza el método .items() para obtener una lista de tuplas con pares clave-valor del diccionario.
# + Muestra cómo utilizar el método .get() para obtener el precio de un producto específico del diccionario.

# %%
productos={"lavandina":{"precio":2000,"stock":100},
           "desodorante":{"precio":1500,"stock":200},"jabon_liquido":{"precio":4000,"stock":150}}

# %%
productos.keys()
# Out:
# dict_keys(['lavandina', 'desodorante', 'jabon_liquido'])

# %%
nombre_producto=list(productos.keys())

# %%
print(nombre_producto)
# Out:
# ['lavandina', 'desodorante', 'jabon_liquido']

# %%
productos.values()
# Out:
# dict_values([{'precio': 2000, 'stock': 100}, {'precio': 1500, 'stock': 200}, {'precio': 4000, 'stock': 150}])

# %%
productos.items()
# Out:
# dict_items([('lavandina', {'precio': 2000, 'stock': 100}), ('desodorante', {'precio': 1500, 'stock': 200}), ('jabon_liquido', {'precio': 4000, 'stock': 150})])

# %% [markdown]
# + Crear una lista de diccionarios que represente información de libros (título, autor, año de publicación).

# %%
libros={"libro1":["juan perez",2022],"libro2":["Juan Fernandez",2014]}

# %% [markdown]
# + Crear un diccionario que contenga listas como valores (por ejemplo, un diccionario de estudiantes y sus materias).

# %%
estudiantes={"estudiante1":["Matematica","practica de lenguaje","fisica"], "estudiante2":["programacion I","programacion II","ciencia de datos"]}

# %% [markdown]
# + Mostrar cómo modificar un valor en una lista dentro de un diccionario y viceversa.

# %%
estudiantes["estudiante1"][1]="programación"

# %%
print(estudiantes["estudiante1"])
# Out:
# ['Matematica', 'programación', 'fisica']
